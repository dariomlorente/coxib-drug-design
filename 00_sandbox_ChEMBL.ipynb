# %% [markdown]
# ## Sandbox to urgently identify a synthesizable coxib
#
# | ChEMBL ID	| IC₅₀ | Aldehyde | Carboxylic | Amine or S | SMILES |
# |---|---|---|---|---|---|
# | CHEMBL5271705 | 90.0 | p-aminobenzaldehyde | hippuric | sulfanilamide | *NS(=O)(=O)c1ccc(N2C(=O)/C(=C/c3ccc(OC(=O)c4ccccc4)cc3)N=C2c2ccccc2)cc1* |
# | CHEMBL5271705 | 87.0 | vanillin benzoate | hippuric | sulfanilamide | *COc1cc(/C=C2\N=C(c3ccccc3)N(c3ccc(S(N)(=O)=O)cc3)C2=O)ccc1OC(=O)c1ccccc1* |
# | CHEMBL5271705 | 92.0 | vanillin benzoate | hippuric | PABA | *COc1cc(/C=C2\N=C(c3ccccc3)N(c3ccc(C(=O)O)cc3)C2=O)ccc1OC(=O)c1ccccc1* |

# %%
#0.6s

from py_utils.prediction import (extract_ic50_by_target,merge_ic50_summary,find_chembl_ids_by_smarts,)

extract_ic50_by_target() # Gets the IC50 values for both COX from the ChEMBL database and saves them into separate files.
merge_ic50_summary()

smarts_output = find_chembl_ids_by_smarts()
